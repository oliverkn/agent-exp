# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
from app.tools import EmailTool


# Initialize email tool
email_tool = EmailTool(client_id="e311ce0a-dc6d-4329-9298-3f40b85e8ead", tenant_id="76929ee5-7d66-4173-b421-9ff1a59cd5e8", email="oliver.knapp@askantis.ch")

email_tool.authenticate()

# Test getting latest email
latest_email = email_tool.get_latest_email()
if latest_email:
    print("Latest Email Details:")
    print(f"Subject: {latest_email['subject']}")
    print(f"From: {latest_email['sender']}")
    print(f"Received: {latest_email['received_time']}")
    print(f"Has Attachments: {latest_email['has_attachments']}")
    print("\nBody Preview:")
    print(latest_email['body'][:200] + "..." if len(latest_email['body']) > 200 else latest_email['body'])
else:
    print("No emails found in the last 24 hours")
# Out:
# Please sign in at: https://microsoft.com/devicelogin
# Use this code: G83QEDYKG
#
# Waiting for user to sign in...
# ✅ Sign-in detected! Access token acquired.
#
# Email 1:
# Subject: Oliver Knapp, your daily digest contains 2 updates across 1 space
# From: confluence@cordys.atlassian.net
# Received: 2025-02-07T07:45:17Z
# Preview: G'day Oliver Knapp,
# Hope you're having a great day. There have been 2 updates since Thursday, February 6, 2025. Want to see more updates? Jump into Confluence
#    Top post
#    250131 + 250206 CLS2AI Workshop Anne+Jeremias
# Anne Marx and 1 other made edit
#
#
# Email 2:
# Subject: simap.ch: Abonnement "Std"
# From: mailmaster@simap.ch
# Received: 2025-02-06T23:37:11Z
# Preview: simap.ch
#  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌
# Guten Tag Oliver Kn
#
#
# Email 3:
# ...

# %%
import requests
import msal

# Microsoft credentials
CLIENT_ID = "e311ce0a-dc6d-4329-9298-3f40b85e8ead"
CLIENT_SECRET = "3q48Q~mfSV1CGBCi7IYEZ_HYxeTHW1dFLNJrMamp"
TENANT_ID = "76929ee5-7d66-4173-b421-9ff1a59cd5e8"

# Microsoft Graph API endpoints
AUTHORITY = f"https://login.microsoftonline.com/{TENANT_ID}"
SCOPES = ["Mail.Read"]

# Initialize the MSAL client (Public Client)
app = msal.PublicClientApplication(CLIENT_ID, authority=AUTHORITY)

# Start device authentication flow
device_flow = app.initiate_device_flow(scopes=SCOPES)
if "user_code" not in device_flow:
    raise Exception("Failed to start device flow. Try again.")

# Show user instructions
print(f"Please sign in at: {device_flow['verification_uri']}")
print(f"Use this code: {device_flow['user_code']}")

# Continuously check if the user has signed in
print("\nWaiting for user to sign in...")
while True:
    token_response = app.acquire_token_by_device_flow(device_flow)
    
    if "access_token" in token_response:
        print("✅ Sign-in detected! Access token acquired.")
        break
    elif "error" in token_response and token_response["error"] == "authorization_pending":
        time.sleep(5)  # Wait and retry
    else:
        raise Exception(f"Authentication failed: {token_response}")

# Fetch emails
access_token = token_response["access_token"]
headers = {"Authorization": f"Bearer {access_token}"}
GRAPH_API_URL = "https://graph.microsoft.com/v1.0/me/messages"

response = requests.get(GRAPH_API_URL, headers=headers)

# Display emails
if response.status_code == 200:
    emails = response.json().get("value", [])
    for i, email in enumerate(emails[:5]):  # Show first 5 emails
        print(f"\nEmail {i+1}:")
        print(f"Subject: {email['subject']}")
        print(f"From: {email['from']['emailAddress']['address']}")
        print(f"Received: {email['receivedDateTime']}")
        print(f"Preview: {email['bodyPreview']}\n")
else:
    print("Error:", response.json())
# Out:
# Please sign in at: https://microsoft.com/devicelogin
# Use this code: GUFVBU6YY
#
# Waiting for user to sign in...
# ✅ Sign-in detected! Access token acquired.
#
# Email 1:
# Subject: Oliver Knapp, your daily digest contains 2 updates across 1 space
# From: confluence@cordys.atlassian.net
# Received: 2025-02-07T07:45:17Z
# Preview: G'day Oliver Knapp,
# Hope you're having a great day. There have been 2 updates since Thursday, February 6, 2025. Want to see more updates? Jump into Confluence
#    Top post
#    250131 + 250206 CLS2AI Workshop Anne+Jeremias
# Anne Marx and 1 other made edit
#
#
# Email 2:
# Subject: simap.ch: Abonnement "Std"
# From: mailmaster@simap.ch
# Received: 2025-02-06T23:37:11Z
# Preview: simap.ch
#  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌
# Guten Tag Oliver Kn
#
#
# Email 3:
# ...

# %%
from O365 import Account

# Microsoft credentials (Client ID only, no secret needed)
CLIENT_ID = "e311ce0a-dc6d-4329-9298-3f40b85e8ead"

account = Account(credentials=(CLIENT_ID,), auth_flow_type="public")

if not account.is_authenticated:
    # Starts Device Code Flow (shows URL & code for sign-in)
    account.authenticate(scopes=["basic", "message_all"])

mailbox = account.mailbox()
inbox = mailbox.inbox_folder()
messages = inbox.get_messages(limit=5)

for msg in messages:
    print(f"From: {msg.sender.address}, Subject: {msg.subject}")
# Out:
# Visit the following url to give consent:
# https://login.microsoftonline.com/common/oauth2/v2.0/authorize?response_type=code&client_id=e311ce0a-dc6d-4329-9298-3f40b85e8ead&redirect_uri=https%3A%2F%2Flogin.microsoftonline.com%2Fcommon%2Foauth2%2Fnativeclient&scope=https%3A%2F%2Fgraph.microsoft.com%2FMail.ReadWrite+https%3A%2F%2Fgraph.microsoft.com%2FMail.Send+https%3A%2F%2Fgraph.microsoft.com%2FUser.Read+offline_access&state=aWOwoBgq5cwYE3pm8JHC6PusxV4a9k&access_type=offline
# Client Error: 401 Client Error: Unauthorized for url: https://graph.microsoft.com/v1.0/me/mailFolders/Inbox/messages?%24top=5 | Error Message: Access token is empty. | Error Code:
# Authentication Flow aborted.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[1], line 14
#      12 mailbox = account.mailbox()
#      13 inbox = mailbox.inbox_folder()
# ---> 14 messages = inbox.get_messages(limit=5)
# ...
